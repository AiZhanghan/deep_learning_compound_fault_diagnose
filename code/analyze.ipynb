# %%
import numpy as np
import pandas as pd

from Analyzer import confusion_matrix

# %%
predict_dic = np.load("../file/predict_dic_2560_single_128_0.001000_0.010000_32_Sat_Apr_11_19_19_38_2020.npz")

# %%
confusion_matrix(predict_dic["y"], (predict_dic["y_hat"] >= 0.5).astype(np.float))
# Out:
#          N   MT   RC    S   CT   OR   IR    B
# N      123    0    0    0    1    0    0    0
# MT       1  115    0    0    0    0    0    0
# RC       1    0  117    0    0    0    0    0
# S        0    0    0  140    0    0    0    0
# CT       6    0    0    0  124    0    0    0
# OR       0    0    0    0    0  124    0    0
# IR      13    0    0    0    0    0  112    0
# B        0    0    0    0    0    0    0  122
# MT_OR  364    0    0  250    0   10    0    0
# MT_IR  594   14    0   14    0    0    0    2
# MT_B   612    0    0    9    0    3    0    0
# RC_OR   34    0    0    0    1  589    0    0
# RC_IR  526    0    0    0   15   82    1    0
# RC_B   566    0   25    0    0    0    0   33
# S_OR   606    0    0    0    0    2    0   16
# S_IR   544    0    0    0    4   76    0    0
# S_B    593    0    0    0   27    1    0    3
# CT_OR  516    0    0    0   10   13    0   85
# CT_IR  289    0    0    0    0  334    0    1
# CT_B   486    0    0    0    9  123    6    0
