# %%
from DataLoader import DataLoader
import matplotlib.pyplot as plt
from matplotlib import rcParams
config = {
    "font.family":'Times New Roman',  # 设置字体类型
}
rcParams.update(config)

# %%
data_loader = DataLoader()

# %%
data_dic, label_dic, info = data_loader.get_frequency_data()

# %%
data_dic.keys()
# Out:
# dict_keys(['1_Normal_Normal', '2_MissingTooth_Normal', '3_RootCrack_Normal', '4_Surface_Normal', '5_ChippedTooth_Normal', '6_Normal_OuterRace', '7_Normal_InnerRace', '8_Normal_Ball', '9_MissingTooth_OuterRace', '10_MissingTooth_InnerRace', '11_MissingTooth_Ball', '12_RootCrack_OuterRace', '13_RootCrack_InnerRace', '14_RootCrack_Ball', '15_Surface_OuterRace', '16_Surface_InnerRace', '17_Surface_Ball', '18_ChippedTooth_OuterRace', '19_ChippedTooth_InnerRace', '20_ChippedTooth_Ball'])

# %%
data_dic["1_Normal_Normal"].shape
# Out:
# (624, 3, 2560)

# %%
data_dic["1_Normal_Normal"][128][0].shape
# Out:
# (2560,)

# %%
import pandas as pd

# %%
df = pd.DataFrame({key: data_dic[key][128][0] for key in data_dic})
# df.drop([x for x in range(1024, 5120)], inplace=True)

# %%
df
# Out:
#       1_Normal_Normal  2_MissingTooth_Normal  3_RootCrack_Normal  \
# 0            0.000885               0.000539            0.001327
# 1            0.000762               0.000032            0.000811
# 2            0.000790               0.000019            0.000517
# 3            0.000347               0.000018            0.000416
# 4            0.000391               0.000018            0.000295
# ...               ...                    ...                 ...
# 2555         0.000008               0.000034            0.000012
# 2556         0.000021               0.000019            0.000016
# 2557         0.000004               0.000033            0.000010
# 2558         0.000010               0.000007            0.000019
# 2559         0.000009               0.000017            0.000015
#
#       4_Surface_Normal  5_ChippedTooth_Normal  6_Normal_OuterRace  \
# 0             0.000298               0.000557            0.000518
# ...

# %%
fig, axes = plt.subplots(nrows=10, ncols=2)
df.plot(subplots=True,
        legend=False, 
        ax=axes,
        sharex=True,
        sharey=True,
#         ylim=(-0.08, 0.08),
        color="black",
        fontsize=12
       )
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:61: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   plot_obj.generate()
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
import Analyzer

# %%
Analyzer.set_figsize((10, 10))

# %%
fig.tight_layout()

# %%
fig

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes[0][0].set_xlabel("(a) N")
# Out:
# Text(0.5, 511.88, '(a) N')

# %%
fig

# %%
fig.legend()
