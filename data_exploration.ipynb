# %% [markdown]
# 测试, 认为数据从excel2csv未出错

# %%
import pandas as pd

# %%
# 实验直接导出来的xlsx数据， raw
pd.read_excel(r"D:\Workspace\Data\20191113_compound_fault\raw\9_MissingTooth_OuterRace\data_19-11-14_1508_624.xlsx")
# Out:
#             扭矩     加速度_1     加速度_2     加速度_3
# 0    -0.901096 -0.003862 -0.001976  0.003616
# 1    -0.898751 -0.002101 -0.005738 -0.001155
# 2    -0.899517  0.008679 -0.006115 -0.002166
# 3    -0.897948  0.013020 -0.000274 -0.000393
# 4    -0.898082  0.006537  0.003724 -0.002180
# ...        ...       ...       ...       ...
# 5115 -0.871663  0.004535 -0.011489 -0.003269
# 5116 -0.859043  0.011928 -0.006971 -0.002374
# 5117 -0.857062  0.008613  0.008655 -0.004232
# 5118 -0.856381 -0.002540  0.000914 -0.003914
# 5119 -0.854666 -0.003246  0.002503 -0.000318
#
# [5120 rows x 4 columns]

# %%
# 整理后csv数据，time
pd.read_csv(r"D:\Workspace\Data\20191113_compound_fault\time\9_MissingTooth_OuterRace\sensor1.csv")
# Out:
#           sensor1
# 0        0.001788
# 1        0.003604
# 2        0.001349
# 3       -0.003517
# 4       -0.005514
# ...           ...
# 3194875  0.004535
# 3194876  0.011928
# 3194877  0.008613
# 3194878 -0.002540
# 3194879 -0.003246
#
# [3194880 rows x 1 columns]
